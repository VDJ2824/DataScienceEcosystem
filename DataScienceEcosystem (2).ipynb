# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# 1-notebook.png
# ![image.png](attachment:27d5ba66-7465-4f27-933b-d70ce6f1555f.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# 2-title.png
# ![image.png](attachment:3f9fec28-09be-41e1-ab57-07673c49fe4e.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# 3-intro.png
# ![image.png](attachment:4b5f56ac-9a50-4122-90d4-d04586839312.png)

# %% [markdown]
# **Objectives** :
# * List popular Data Science Languages
# * List commonly used libraries for Data Science
# * List Data Science Tools
# * Perform basic arithmetic tasks.

# %% [markdown]
# 10-objectives.png
# ![image.png](attachment:db2f4db7-4009-4e7d-8501-2ab7626c5599.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. Java
# 3. SQL
# 4. R
# 5. C/C++
# 6. Julia

# %% [markdown]
# 4-dslanguages.png
# ![image.png](attachment:ae7396af-3fb9-45b1-b0e9-b8e23c4a3852.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. dplyr
# 3. NumPy
# 4. SciPy
# 5. Matplotlib
# 6. Tensorflow

# %% [markdown]
# 5-dslibraries.png
# ![image.png](attachment:d2b19454-1438-4267-b646-60d87a13ec11.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | RStudio |
# | Apache Spark |
# | Apache Hadoop |

# %% [markdown]
# 6-dstools.png
#
# ![image.png](attachment:a12d77c9-3dd0-4caa-9784-f3f9bce52310.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# 7-introarithmetic.png
# ![image.png](attachment:17116d8f-b96b-455a-bf0a-ac82d1005264.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5

# %% [markdown]
# 8-multiplyandaddintegers.png
# ![image.png](attachment:82277d40-2c66-4691-b776-d4051ecf8767.png)

# %%
# This will convert 200 minutes to hours by diving by 60.
200/60

# %% [markdown]
# 9-hourstominutes.png
# ![image.png](attachment:c90d2af9-ac00-4a55-87ef-ab01d8eb792d.png)

# %% [markdown]
# ## Author
# Varima Dudeja

# %% [markdown]
# 11-authordetails.png
# ![image.png](attachment:4ba015b8-f3f7-4376-997d-b354b5bc7a04.png)
